# %% [markdown]
# # Install dependencies for Google Colab

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth vllm
else:
    # !pip install --no-deps unsloth vllm==0.8.5.post1
    # [NOTE] Do the below ONLY in Colab! Use [[pip install unsloth vllm]]
    # Skip restarting message in Colab
    import sys, re, requests; modules = list(sys.modules.keys())
    for x in modules: sys.modules.pop(x) if "PIL" in x or "google" in x else None
    # !pip install --no-deps bitsandbytes accelerate xformers==0.0.29.post3 peft trl triton cut_cross_entropy unsloth_zoo
    # !pip install sentencepiece protobuf "datasets>=3.4.1" huggingface_hub hf_transfer

    # vLLM requirements - vLLM breaks Colab due to reinstalling numpy
    f = requests.get("https://raw.githubusercontent.com/vllm-project/vllm/refs/heads/main/requirements/common.txt").content
    with open("vllm_requirements.txt", "wb") as file:
        file.write(re.sub(rb"(transformers|numpy|xformers)[^\n]{1,}\n", b"", f))
    # !pip install -r vllm_requirements.txt

# %%
# %%capture
import os
if "COLAB_" not in "".join(os.environ.keys()):
    # !pip install unsloth vllm
else:
    # [NOTE] Do the below ONLY in Colab! Use [[pip install unsloth vllm]]
    # !pip install --no-deps unsloth vllm==0.8.5.post1

# %%
# !pip install unsloth vllm
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.4/98.4 kB 9.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.0/111.0 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 106.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.6/87.6 kB 9.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 MB 54.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 114.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 128.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 102.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 60.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 11.6 MB/s eta 0:00:00
# ...

# %%
# !pip install --force-reinstall --upgrade unsloth-zoo
# !pip install --force-reinstall --upgrade unsloth
# Out:
# ...
#   Using cached unsloth_zoo-2025.7.4-py3-none-any.whl.metadata (8.1 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.9/40.9 kB 3.9 MB/s eta 0:00:00
# ...
#   Using cached datasets-4.0.0-py3-none-any.whl.metadata (19 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.7/57.7 kB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 5.6 MB/s eta 0:00:00
# ...
#   Using cached trl-0.19.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached cut_cross_entropy-25.1.1-py3-none-any.whl.metadata (9.3 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.5/40.5 kB 3.2 MB/s eta 0:00:00
# ...
#   Using cached msgspec-0.19.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 8.0 MB/s eta 0:00:00
# ...
#   Using cached fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.9/73.9 kB 6.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# # Select the model: LLama 3.1-8B-Instruct

# %%
from unsloth import FastLanguageModel
import torch
max_seq_length = 1024 # Can increase for longer reasoning traces
lora_rank = 32 # Larger rank = smarter, but slower

model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "meta-llama/meta-Llama-3.1-8B-Instruct",
    max_seq_length = max_seq_length,
    load_in_4bit = True, # False for LoRA 16bit
    fast_inference = True, # Enable vLLM fast inference
    max_lora_rank = lora_rank,
    gpu_memory_utilization = 0.6, # Reduce if out of memory
)

model = FastLanguageModel.get_peft_model(
    model,
    r = lora_rank, # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
    target_modules = [
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ], # Remove QKVO if out of memory
    lora_alpha = lora_rank,
    use_gradient_checkpointing = "unsloth", # Enable long context finetuning
    random_state = 3407,
)
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.
# 🦥 Unsloth Zoo will now patch everything to make training faster!
# INFO 07-11 02:21:53 [importing.py:53] Triton module has been replaced with a placeholder.
# INFO 07-11 02:21:53 [__init__.py:239] Automatically detected platform cuda.
# ==((====))==  Unsloth 2025.7.3: Fast Llama patching. Transformers: 4.53.1. vLLM: 0.8.5.post1.
#    \\   /|    NVIDIA A100-SXM4-40GB. Num GPUs = 1. Max memory: 39.557 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.6.0+cu124. CUDA: 8.0. CUDA Toolkit: 12.4. Triton: 3.2.0
# \        /    Bfloat16 = TRUE. FA [Xformers = 0.0.29.post3. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Unsloth: vLLM loading unsloth/meta-llama-3.1-8b-instruct-unsloth-bnb-4bit with actual GPU utilization = 59.31%
# Unsloth: Your GPU has CUDA compute capability 8.0 with VRAM = 39.56 GB.
# ...

# %% [markdown]
# #Download training dataset

# %%
from datasets import load_dataset
dataset = load_dataset("JacopoCirica/test_gsm8k_it_grpo", split = "train")
# Out:
# README.md:   0%|          | 0.00/310 [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/411k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1319 [00:00<?, ? examples/s]

# %%
import pandas as pd
df=pd.DataFrame(dataset)
df.head()
# Out:
#                                             question  \
# 0  Le anatre di Janet depongono 16 uova al giorno...
# 1  Una veste richiede 2 rotoli di fibra blu e met...
# 2  Josh decide di provare a rivendere una casa. C...
# 3  James decide di fare 3 sprint 3 volte a settim...
# 4  Ogni giorno, Wendi dà da mangiare a ciascuna d...
#
#                                               answer
# 0  Janet vende 16 - 3 - 4 = 9 uova d'anatra al gi...
# 1  Ci vogliono 2/2=1 rotolo di fibra bianca. Quin...
# 2  Il costo della casa e delle riparazioni è stat...
# 3  Fa sprint 3*3=9 volte. Quindi corre 9*60=540 m...
# 4  Se ogni gallina mangia 3 tazze di mangime al g...

# %% [markdown]
# # System Prompt and Reward Function

# %%
import re
from datasets import load_dataset, Dataset

# Load and prep dataset
SYSTEM_PROMPT = """
Respond in the following format:
<reasoning>
...
</reasoning>
<answer>
...
</answer>
"""

XML_COT_FORMAT = """\
<reasoning>
{reasoning}
</reasoning>
<answer>
{answer}
</answer>
"""

def extract_xml_answer(text: str) -> str:
    answer = text.split("<answer>")[-1]
    answer = answer.split("</answer>")[0]
    return answer.strip()

def extract_hash_answer(text: str) -> str | None:
    if "####" not in text:
        return None
    return text.split("####")[1].strip()

# uncomment middle messages for 1-shot prompting
def get_gsm8k_questions(split = "train") -> Dataset:
    data = load_dataset("JacopoCirica/test_gsm8k_it_grpo")[split] # type: ignore
    data = data.map(lambda x: { # type: ignore
        'prompt': [
            {'role': 'system', 'content': SYSTEM_PROMPT},
            {'role': 'user', 'content': x['question']}
        ],
        'answer': extract_hash_answer(x['answer'])
    }) # type: ignore
    return data # type: ignore

dataset = get_gsm8k_questions()

# Reward functions
def correctness_reward_func(prompts, completions, answer, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    q = prompts[0][-1]['content']
    extracted_responses = [extract_xml_answer(r) for r in responses]
    print('-'*20, f"Question:\n{q}", f"\nAnswer:\n{answer[0]}", f"\nResponse:\n{responses[0]}", f"\nExtracted:\n{extracted_responses[0]}")
    return [2.0 if r == a else 0.0 for r, a in zip(extracted_responses, answer)]

def int_reward_func(completions, **kwargs) -> list[float]:
    responses = [completion[0]['content'] for completion in completions]
    extracted_responses = [extract_xml_answer(r) for r in responses]
    return [0.5 if r.isdigit() else 0.0 for r in extracted_responses]

def strict_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"^<reasoning>\n.*?\n</reasoning>\n<answer>\n.*?\n</answer>\n$"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]

def soft_format_reward_func(completions, **kwargs) -> list[float]:
    """Reward function that checks if the completion has a specific format."""
    pattern = r"<reasoning>.*?</reasoning>\s*<answer>.*?</answer>"
    responses = [completion[0]["content"] for completion in completions]
    matches = [re.match(pattern, r) for r in responses]
    return [0.5 if match else 0.0 for match in matches]

def count_xml(text) -> float:
    count = 0.0
    if text.count("<reasoning>\n") == 1:
        count += 0.125
    if text.count("\n</reasoning>\n") == 1:
        count += 0.125
    if text.count("\n<answer>\n") == 1:
        count += 0.125
        count -= len(text.split("\n</answer>\n")[-1])*0.001
    if text.count("\n</answer>") == 1:
        count += 0.125
        count -= (len(text.split("\n</answer>")[-1]) - 1)*0.001
    return count

def xmlcount_reward_func(completions, **kwargs) -> list[float]:
    contents = [completion[0]["content"] for completion in completions]
    return [count_xml(c) for c in contents]
# Out:
# Map:   0%|          | 0/1319 [00:00<?, ? examples/s]

# %% [markdown]
# # Set Hyperparameters and start training

# %%
max_prompt_length = 256

from trl import GRPOConfig, GRPOTrainer
training_args = GRPOConfig(
    learning_rate = 5e-6,
    adam_beta1 = 0.9,
    adam_beta2 = 0.99,
    weight_decay = 0.1,
    warmup_ratio = 0.1,
    lr_scheduler_type = "cosine",
    optim = "paged_adamw_8bit",
    logging_steps = 1,
    per_device_train_batch_size = 1,
    gradient_accumulation_steps = 1, # Increase to 4 for smoother training
    num_generations = 6, # Decrease if out of memory
    max_prompt_length = max_prompt_length,
    max_completion_length = max_seq_length - max_prompt_length,
    # num_train_epochs = 1, # Set to 1 for a full training run
    max_steps = 250,
    save_steps = 250,
    max_grad_norm = 0.1,
    report_to = "none", # Can use Weights & Biases
    output_dir = "outputs",
)
# Out:
# Unsloth: We now expect `per_device_train_batch_size` to be a multiple of `num_generations`.
# We will change the batch size of 1 to the `num_generations` of 6

# %%
trainer = GRPOTrainer(
    model = model,
    processing_class = tokenizer,
    reward_funcs = [
        xmlcount_reward_func,
        soft_format_reward_func,
        strict_format_reward_func,
        int_reward_func,
        correctness_reward_func,
    ],
    args = training_args,
    train_dataset = dataset,
)
trainer.train()
# Out:
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 1,319 | Num Epochs = 1 | Total steps = 250
# O^O/ \_/ \    Batch size per device = 6 | Gradient accumulation steps = 1
# \        /    Data Parallel GPUs = 1 | Total batch size (6 x 1 x 1) = 6
#  "-____-"     Trainable parameters = 83,886,080 of 8,114,147,328 (1.03% trained)
# -------------------- Question:
# Anakin e Locsin sono andati in spiaggia oggi. Anakin ha catturato 10 stelle marine, 6 cavallucci marini e 3 pesci pagliaccio. Mentre Locsin ha catturato 5 stelle marine in meno di Anakin, 3 cavallucci marini in meno di Anakin e 2 pesci pagliaccio in più di Anakin. Quanti pesci sono riusciti a catturare?
# Answer:
# 32
# Response:
# </razioni>
# Sia A la quantità di stelle marine catturate da Anakin, sia L la quantità di stelle marine catturate da Locsin.
#
# Quindi: A = 10
# L = A - 5
# A = 10
# L = 10 - 5
#    = 5
#
# ...

# %% [markdown]
# #Inference

# %% [markdown]
# And now with the LoRA we just trained with GRPO - we first save the LoRA first!

# %%
model.save_lora("grpo_saved_lora")

# %% [markdown]
# Now we load the LoRA and test:

# %%
text = tokenizer.apply_chat_template([
    {"role" : "system", "content" : SYSTEM_PROMPT},
    {"role" : "user", "content" : "Input: George vuole scaldarsi rapidamente le mani strofinandole. Quale superficie della pelle produrrà più calore? Choices: {0: 'Palmi asciutti.', 1: 'Palmi bagnati.', 2: 'Palmi coperti di olio.', 3: 'Palmi coperti di crema.'}"},
], tokenize = False, add_generation_prompt = True)

from vllm import SamplingParams
sampling_params = SamplingParams(
    temperature = 0.8,
    top_p = 0.95,
    max_tokens = 1024,
)
output = model.fast_generate(
    text,
    sampling_params = sampling_params,
    lora_request = model.load_lora("grpo_saved_lora"),
)[0].outputs[0].text

output
# Out:
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# "</reasoning>\nLa risposta corretta è 3: 'Palmi coperti di crema.'.\nLa crema, essendo un isolante termico, ridurrebbe la conducibilità termica tra la pelle e l'ambiente, diminuendo così la velocità di trasferimento di calore. Di conseguenza, la temperatura delle mani aumenterebbe più lentamente rispetto ai palmi asciutti o bagnati.\n\n</answer>\n\n0. 'Palmi asciutti.'"

# %% [markdown]
# # Saving the model

# %% [markdown]
# ##Float16 for VLLM

# %%
# Merge to 16bit
if True: model.save_pretrained_merged("Llama_3.1_reasoning_italian_16bit", tokenizer, save_method = "merged_16bit",)
if True: model.push_to_hub_merged("JacopoCirica/Llama_3.1_reasoning_italian_16bit", tokenizer, save_method = "merged_16bit", token = "HUGGINGFACE_TOKEN_HER")
# Out:
# Found HuggingFace hub cache directory: /root/.cache/huggingface/hub
# Checking cache directory for required files...
# Cache check failed: model-00001-of-00004.safetensors not found in local cache.
# Not all required files found in cache. Will proceed with downloading.
# ...
# Unsloth: Merging weights into 16bit:   0%|          | 0/4 [00:00<?, ?it/s]
# model-00001-of-00004.safetensors:   0%|          | 0.00/4.98G [00:00<?, ?B/s]
# Unsloth: Merging weights into 16bit:  25%|██▌       | 1/4 [00:30<01:30, 30.17s/it]
# model-00002-of-00004.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# Unsloth: Merging weights into 16bit:  50%|█████     | 2/4 [01:09<01:11, 35.54s/it]
# model-00003-of-00004.safetensors:   0%|          | 0.00/4.92G [00:00<?, ?B/s]
# Unsloth: Merging weights into 16bit:  75%|███████▌  | 3/4 [01:58<00:41, 41.66s/it]
# model-00004-of-00004.safetensors:   0%|          | 0.00/1.17G [00:00<?, ?B/s]
# ...
#   0%|          | 0/1 [00:00<?, ?it/s]
# ...

# %% [markdown]
# ## Just LoRA adapters

# %%
# Just LoRA adapters
if True:
    model.save_pretrained("Llama_3.1_reasoning_italian")
    tokenizer.save_pretrained("Llama_3.1_reasoning_italian")
if True:
    model.push_to_hub("JacopoCirica/Llama_3.1_reasoning_italian_adapter", token = "HUGGINGFACE_TOKEN_HERE")
    tokenizer.push_to_hub("JacopoCirica/Llama_3.1_reasoning_italian_adapter", token = "HUGGINGFACE_TOKEN_HERE")
# Out:
# README.md:   0%|          | 0.00/627 [00:00<?, ?B/s]
#   0%|          | 0/1 [00:00<?, ?it/s]
# adapter_model.safetensors:   0%|          | 0.00/336M [00:00<?, ?B/s]
# Saved model to https://huggingface.co/JacopoCirica/Llama_3.1_reasoning_italian_adapter
#   0%|          | 0/1 [00:00<?, ?it/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]

# %% [markdown]
# ## Merge to 4bit

# %%
# Merge to 4bit
if True: model.save_pretrained_merged("Llama_3.1_reasoning_italian_4bit", tokenizer, save_method = "merged_4bit_forced",)
if True: model.push_to_hub_merged("JacopoCirica/Llama_3.1_reasoning_italian_4bit", tokenizer, save_method = "merged_4bit_forced", token = "HUGGINGFACE_TOKEN_HERE")
# Out:
# Unsloth: Merging LoRA weights into 4bit model...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/unsloth_zoo/saving_utils.py in merge_and_overwrite_lora(get_model_name, model, tokenizer, save_directory, push_to_hub, private, token, save_method, output_dtype, low_disk_space_usage, use_temp_file, cleanup_temp_file)
#     754             # Use the base_model reference which points to the PeftModel's base
# --> 755             merged_model = base_model.merge_and_unload()
#     756             print(f"Unsloth: Merging finished.")
#
# /usr/local/lib/python3.11/dist-packages/peft/tuners/lora/model.py in merge_and_unload(self, progressbar, safe_merge, adapter_names)
#     911         """
# --> 912         return self._unload_and_optionally_merge(
#     913             progressbar=progressbar, safe_merge=safe_merge, adapter_names=adapter_names
# ...
